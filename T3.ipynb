# %%
import pandas as pd
import time
import datetime

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('./subscribers.csv')
df.head()
# Out:
#    Unnamed: 0     subid package_type  num_weekly_services_utilized  \
# 0      162502  21724479      economy                           NaN
# 1      380374  23383224         base                           NaN
# 2      496617  26844789     enhanced                           3.0
# 3      356799  29417030         base                           NaN
# 4      681701  26723159         base                           4.0
#
#   preferred_genre                 intended_use  weekly_consumption_hour  \
# 0          comedy  access to exclusive content                      NaN
# 1          comedy  access to exclusive content                22.951579
# 2        regional                  replace OTT                36.001186
# 3           drama                  replace OTT                20.051667
# 4          comedy                  replace OTT                22.951579
#
#    num_ideal_streaming_services   age male_TF country attribution_technical  \
# ...

# %%
df['account_creation_date'] = pd.to_datetime(df['account_creation_date'])
df['trial_end_date'] = pd.to_datetime(df['trial_end_date'])
df['last_payment'] = pd.to_datetime(df['last_payment'])
df['next_payment'] = pd.to_datetime(df['next_payment'])
df['cancel_date'] = pd.to_datetime(df['cancel_date'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227628 entries, 0 to 227627
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Unnamed: 0                    227628 non-null  int64
#  1   subid                         227628 non-null  int64
#  2   package_type                  192054 non-null  object
#  3   num_weekly_services_utilized  117178 non-null  float64
#  4   preferred_genre               191302 non-null  object
#  5   intended_use                  224079 non-null  object
#  6   weekly_consumption_hour       189698 non-null  float64
#  7   num_ideal_streaming_services  115458 non-null  float64
#  8   age                           192459 non-null  float64
#  9   male_TF                       227359 non-null  object
#  10  country                       227628 non-null  object
#  11  attribution_technical         227628 non-null  object
# ...

# %%
df1 = df[(df['account_creation_date'] > '2019-07-01 00:00:00') & (df['account_creation_date'] < '2019-07-31 23:59:59')]
print(df1.shape[0])

df2 = df[(df['account_creation_date'] > '2019-08-01 00:00:00') & (df['account_creation_date'] < '2019-08-31 23:59:59')]
print(df2.shape[0])

df3 = df[(df['account_creation_date'] > '2019-09-01 00:00:00') & (df['account_creation_date'] < '2019-09-30 23:59:59')]
print(df3.shape[0])

df4 = df[(df['account_creation_date'] > '2019-10-01 00:00:00') & (df['account_creation_date'] < '2019-10-31 23:59:59')]
print(df4.shape[0])

df5 = df[(df['account_creation_date'] > '2019-11-01 00:00:00') & (df['account_creation_date'] < '2019-11-30 23:59:59')]
print(df5.shape[0])

df6 = df[(df['account_creation_date'] > '2019-12-01 00:00:00') & (df['account_creation_date'] < '2019-12-31 23:59:59')]
print(df6.shape[0])

df7 = df[(df['account_creation_date'] > '2020-01-01 00:00:00') & (df['account_creation_date'] < '2020-01-31 23:59:59')]
print(df7.shape[0])

df8 = df[(df['account_creation_date'] > '2020-02-01 00:00:00') & (df['account_creation_date'] < '2020-02-28 23:59:59')]
print(df8.shape[0])
# Out:
# 25708
# 25434
# 20190
# 22412
# 26827
# 25339
# 24843
# 26753

# %%
df_list = [df1,df2,df3,df4,df5,df6,df7,df8]
attr_list = ['bing','display','facebook','search','youtube']

for i in df_list:
    for j in attr_list:
        dfx = i[i['attribution_technical'] == j]
        print(dfx.shape[0])
# Out:
# 120
# 44
# 10011
# 1328
# 8
# 71
# 74
# 9855
# 1939
# 15
# 84
# 12
# 6129
# 1852
# 2
# 86
# 50
# 9489
# 2333
# 11
# 103
# 90
# 12994
# 2510
# 47
# 28
# 112
# 9288
# 3770
# 76
# 172
# 536
# 6289
# 4073
# 370
# 287
# 333
# 7525
# 4127
# 202
